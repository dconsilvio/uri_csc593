# %% [markdown]
# # Assignment 8
#
# *(Due Saturday, November 16, 2019 at noon.)*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib notebook

# %% [markdown]
# Load your dataset and create at least one visualization involving at least two variables (columns). Explain the relevance of this graph in the Markdown cell below, and use comments to document the code you use to produce it.

# %%
import numpy as np
import pandas as pd
dataset = pd.read_csv('../dataset/dataset2.csv')
dataset.head()
# Out:
#       GEO.id GEO.id2 GEO.display-label POPGROUP.id  \
# 0         Id     Id2         Geography          Id
# 1  0100000US     NaN     United States           3
# 2  0100000US     NaN     United States           5
# 3  0100000US     NaN     United States           9
# 4  0100000US     NaN     United States          31
#
#                               POPGROUP.display-label  \
# 0                                   Population Group
# 1  White alone or in combination with one or more...
# 2  Black or African American alone or in combinat...
# 3  American Indian and Alaska Native alone or in ...
# 4  Asian alone or in combination with one or more...
#
#                                             EST_VC03  \
# 0  Estimate; TOTAL NUMBER OF RACES REPORTED - Tot...
# 1                                          244691364
# 2                                           45789188
# 3                                            5631945
# 4                                           21646070
#
# ...

# %%
#the population estimate of total races reported, compared with the total margin of error,
#indicates not much likelihood of error at all 
ds = dataset[1:]
ds.head()
ds.EST_VC03 = ds.EST_VC03.astype(np.int64)
ds.MOE_VC03 = ds.MOE_VC03.astype(np.int64)
x = ds.EST_VC03.sum()
y = ds.MOE_VC03.sum()
plen = ds.groupby('GEO.display-label').sum()[['EST_VC03', 'MOE_VC03']]
fig, ax = plt.subplots(figsize=(14,8))
ax.bar(['estimate', 'margin of error'], [x,y])
plt.show(dataset)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-01ad56a0a8a3> in <module>
#       8 fig, ax = plt.subplots(figsize=(14,8))
#       9 ax.bar(['estimate', 'margin of error'], [x,y])
# ---> 10 plt.show(dataset)
#
# //anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     261     """
#     262     global _show
# --> 263     return _show(*args, **kw)
#     264
#     265
#
# //anaconda3/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      43         # only call close('all') if any to close
#      44         # close triggers gc.collect, which can be slow
# ---> 45         if close and Gcf.get_all_fig_managers():
#      46             matplotlib.pyplot.close('all')
#      47
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
# ...
